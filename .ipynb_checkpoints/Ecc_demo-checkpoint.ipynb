# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import sys
# %matplotlib inline
np.set_printoptions(suppress=True)

# %%
# Read the images to be aligned
im11 =  cv2.imread("images/im1.jpg",1);
im21 =  cv2.imread("images/im2.jpg",1);

# Convert images to grayscale
im1_gray = cv2.cvtColor(im11,cv2.COLOR_BGR2GRAY)
im2_gray = cv2.cvtColor(im21,cv2.COLOR_BGR2GRAY)

# Find size of image1
sz = im11.shape

# Define the motion model
warp_mode = cv2.MOTION_HOMOGRAPHY # cv2.MOTION_HOMOGRAPHY , cv2.MOTION_TRANSLATION

# Define 2x3 or 3x3 matrices and initialize the matrix to identity
if warp_mode == cv2.MOTION_HOMOGRAPHY :
    warp_matrix = np.eye(3, 3, dtype=np.float32)
else :
    warp_matrix = np.eye(2, 3, dtype=np.float32)

# Specify the number of iterations.
number_of_iterations = 200;

# Specify the threshold of the increment
# in the correlation coefficient between two iterations
termination_eps = 1e-10;

# Define termination criteria
criteria = (cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, number_of_iterations,  termination_eps)

# Run the ECC algorithm. The results are stored in warp_matrix.
(cc, warp_matrix) = cv2.findTransformECC (im1_gray,im2_gray,warp_matrix, warp_mode, criteria,inputMask=None,gaussFiltSize=5)
print(warp_matrix)
if warp_mode == cv2.MOTION_HOMOGRAPHY :
    # Use warpPerspective for Homography 
    im2_aligned = cv2.warpPerspective (im2_gray, warp_matrix, (sz[1],sz[0]), flags=cv2.INTER_LINEAR + cv2.WARP_INVERSE_MAP)
else :
    # Use warpAffine for Translation, Euclidean and Affine
    im2_aligned = cv2.warpAffine(im2_gray, warp_matrix, (sz[1],sz[0]), flags=cv2.INTER_LINEAR + cv2.WARP_INVERSE_MAP);

# Show final results
#cv2.imshow("Image 1", im1)
#cv2.imshow("Image 2", im2)
#cv2.imshow("Aligned Image 2", im2_aligned)
#cv2.waitKey(0)
# Out:
# [[   1.0681463     0.07726914 -120.24116   ]
#  [  -0.0399471     1.0799758    99.832535  ]
#  [   0.00000504    0.00001976    1.        ]]

# %%
plt.imshow(im11[:,:,::-1])

# %%
plt.imshow(im21[:,:,::-1])

# %%
plt.imshow(im2_aligned)

# %%
fused = np.zeros_like(im11)
fused[:,:,0] = im1_gray
fused[:,:,1] = im2_aligned

# %%
plt.imshow(fused)

# %%
fused.shape
# Out:
# (3072, 4096, 3)

# %%
cv2.imwrite('output/fused.jpg',fused[:,:,::-1])
# Out:
# True
